# %% [markdown]
# ### **Notes and References**
#
# Hi. I'm currently learning android development and this is my personal learning notebook.
#
# All the code is from Coding with Evan and you can watch the original tutorial in the below link. Have fun learning :) !
#
# https://www.youtube.com/watch?v=sjkDbxyoNW0&ab_channel=CodingWithEvan

# %% [markdown]
# # New Functions & Concepts

# %% [markdown]
# # 1 Testing

# %% [markdown]
# ## Emulator - will error!!

# %%
test = "/content/here/MyDrive/Android/OCRApp_test.png"
show(test)
# Out:
# <PIL.Image.Image image mode=RGB size=1764x850 at 0x7F73FE3FE4D0>

# %% [markdown]
# ## On real device

# %%
test = "/content/here/MyDrive/Android/TextReaderApp/result text reader.png"
show(test)
# Out:
# <PIL.Image.Image image mode=RGB size=1609x781 at 0x7FEE56EAE350>

# %% [markdown]
# # 2 Debugging

# %% [markdown]
# ### **Error log - DynamiteModule Exception**
#
#     2021-09-26 17:46:55.958 17166-17166/com.example.textreaderapp E/Vision:
#     Error loading module com.google.android.gms.vision.ocr
#     optional module true: com.google.android.gms.dynamite
#     DynamiteModule$LoadingException: No acceptable module found.
#     Local version is 0 and remote version is 0.

# %% [markdown]
# ### Solution
# - Cause: possibly Version conflict
#
# *It's because either your device or emulator has an out-dated version of Google Play services. Right above your error you should see something in the log cat that says*
#
# *Google Play services out of date. Requires 3264100 but found 3225132*
#
# *Just update the Google Play services and it'll work.*
#
# https://stackoverflow.com/questions/54542514/no-acceptable-module-found-local-version-is-0-and-remote-version-is-0
#
# - **Solution: update Google Play services.**
#
# https://stackoverflow.com/questions/35476182/updating-google-play-services-in-emulator

# %% [markdown]
# ## **TextRcogniser Operationality**
# - recogniser is NOT operational.

# %%
error = "/content/here/MyDrive/Android/OCRApp_error.png"
show(error)
# Out:
# <PIL.Image.Image image mode=RGB size=934x710 at 0x7F73FE413BD0>

# %% [markdown]
# ## TextRecognizer.isOperational() API always returns false
#
# https://stackoverflow.com/questions/46410777/textrecognizer-isoperational-api-always-returns-false
